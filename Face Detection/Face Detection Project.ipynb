# %% [markdown]
# ## Import Libraries

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the Image and Display shape

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image1.jpg')
display (image.shape)
# Out:
# (183, 275, 3)

# %% [markdown]
# ### Display the Image with Matplotlib

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# ### Print the Image Values and Pixel Values

# %%
print(image)
# Out:
# [[[ 95 143 191]
#   [ 95 143 191]
#   [ 96 140 187]
#   ...
#   [ 57 120 154]
#   [ 59 130 157]
#   [ 64 135 162]]
#
#  [[ 95 143 191]
#   [ 95 143 191]
#   [ 96 140 187]
#   ...
#   [ 54 117 151]
#   [ 59 129 158]
#   [ 67 137 166]]
#
#  [[ 96 145 191]
#   [ 96 145 191]
#   [ 97 141 188]
#   ...
#   [ 42 104 142]
#   [ 52 119 152]
#   [ 65 132 165]]
#
#  ...
#
#  [[199 205 228]
#   [194 205 227]
#   [181 203 221]
#   ...
#   [143 188 239]
#   [145 188 239]
#   [145 188 239]]
#
#  [[196 202 225]
#   [196 207 229]
#   [179 201 219]
#   ...
#   [144 189 240]
#   [146 189 240]
#   [146 189 240]]
#
#  [[194 200 223]
#   [195 206 228]
#   [185 207 225]
#   ...
#   [160 206 254]
#   [162 205 254]
#   [162 205 254]]]

# %% [markdown]
# ### Display the Image with CV2

# %%
cv2.imshow('', image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Resize the Image

# %%
image = cv2.resize(image, (800, 600))
 
image.shape
# Out:
# (600, 800, 3)

# %% [markdown]
# ### Display the Image to Small size Image

# %%
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Gray Image  is Convert to Back and White

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### display the Size of the Gray Image(Back and White)

# %%
display (image_gray.shape)
# Out:
# (600, 800)

# %% [markdown]
# ### Load Face Detector . Xml file

# %%
face_detector = cv2.CascadeClassifier('C:\\Program Files\\Project\\Face Detection\\haarcascade_frontalface_default.xml')
face_detector
# Out:
# < cv2.CascadeClassifier 0000022D68C96490>

# %% [markdown]
# ### Display the Face Detection co-ordinates values

# %%
detections = face_detector.detectMultiScale(image_gray)
display (detections)
# Out:
# array([[182, 101,  88,  88],
#        [542,  49,  93,  93],
#        [325, 108,  83,  83],
#        [ 80,  78, 103, 103],
#        [438, 112,  86,  86]])

# %% [markdown]
# ### Display the length and Number of face detected

# %%
display (len(detections))
# Out:
# 5

# %% [markdown]
# ### Display each detected face with rectangle

# %%
x=390  # X - Co ordinates 
y=323  # Y- Co ordinates 
w=56   # Face Width
h=56   # Face Height 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 1)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Second detected face with rectangle

# %%
x=115  # X - Co ordinates 
y=124  # Y- Co ordinates 
w=52   # Face Width
h=52   # Face Height 
 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Third detected face with rectangle

# %%
x=475  # X - Co ordinates 
y=123  # Y- Co ordinates 
w=59   # Face Width
h=59  # Face Height 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Display all detected face with rectangle

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(0)
plt.show()

# %% [markdown]
# ### face detection by colour image

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image1.jpg')
display (image.shape)
image = cv2.resize(image, (800, 600)) # Resize image
display (image.shape) 
detections = face_detector.detectMultiScale(image)
display (detections)
# Out:
# (183, 275, 3)
# (600, 800, 3)
# array([[542,  49,  93,  93],
#        [182, 101,  88,  88],
#        [325, 108,  83,  83],
#        [ 80,  78, 103, 103],
#        [438, 112,  86,  86]])

# %% [markdown]
# ### Display  the Image

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %% [markdown]
# ### parameter - Scale factor

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image1.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[182, 102,  87,  87],
#        [324, 109,  83,  83],
#        [540,  48,  95,  95],
#        [ 79,  76, 105, 105],
#        [438, 113,  86,  86]])

# %% [markdown]
# ### Load Image and display It

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image1.jpg')
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image1.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[ 63,  30,  29,  29],
#        [187,  14,  30,  30],
#        [111,  31,  28,  28],
#        [151,  34,  27,  27],
#        [ 31,  24,  31,  31]])
# 29 29
# 30 30
# 28 28
# 27 27
# 31 31

# %% [markdown]
# ### parameter -min Neighbors-It reduces false positive

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image1.jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,minNeighbors=7)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[ 63,  30,  29,  29],
#        [151,  33,  29,  29]])
# 29 29
# 29 29

# %% [markdown]
# ### Minsize and Maxsize

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image1.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,minNeighbors=7,minSize=(20,20), maxSize=(100,100))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[ 63,  30,  29,  29],
#        [151,  33,  29,  29]])
# 29 29
# 29 29

# %% [markdown]
# ## Eye Detector

# %% [markdown]
# ### Load Eye detector . Xml file

# %%
eye_detector= cv2.CascadeClassifier('C:\\Program Files\\Project\\Face Detection\\haarcascade_eye.xml')

display (eye_detector)
# Out:
# < cv2.CascadeClassifier 0000022D6856C4B0>

# %% [markdown]
# ### Use Both Eye  And Face Detection

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image1.jpg')
display (image.shape)

image = cv2.resize(image, (1600,1000)) # Resize image
print(image.shape)
face_detections = face_detector.detectMultiScale(image, scaleFactor = 1.3, minSize = (30,30))
for (x, y, w, h) in face_detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image, scaleFactor = 1.1, minNeighbors=10, maxSize=(60,60))

for (x, y, w, h) in eye_detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# (183, 275, 3)
# (1000, 1600, 3)
# 49 49
# 51 51
# 46 46
# 39 39
# 45 45
# 48 48
# 46 46
# 47 47
# 45 45
# 42 42
# 50 50
# 49 49
# 50 50
# 47 47
# 41 41

# %% [markdown]
# ## Full Body Detector

# %% [markdown]
# ### Load . Xml file

# %%
full_detector  = cv2.CascadeClassifier('C:\\Program Files\\Project\\Face Detection\\fullbody.xml')
display (full_detector)
# Out:
# < cv2.CascadeClassifier 00000298DE3EA890>

# %% [markdown]
# ### Load Image

# %%
image = cv2.imread('C:\\Program Files\\Project\\Face Detection\\image2.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# (294, 626, 3)

# %% [markdown]
# ### Body detector

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray,scaleFactor = 1.05,minNeighbors=5,minSize = (50,50)) 
for(x,y,w,h) in detections:
        cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
